# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\Admin\Downloads\house_price_prediction.csv")

# %%
data
# Out:
#        avg_income  avg_area_house_age  avg_area_num_rooms  avg_bedrooms  \
# 0     79545.45857            5.682861            7.009188          4.09
# 1     79248.64245            6.002900            6.730821          3.09
# 2     61287.06718            5.865890            8.512727          5.13
# 3     63345.24005            7.188236            5.586729          3.26
# 4     59982.19723            5.040555            7.839388          4.23
# ...           ...                 ...                 ...           ...
# 5007  60567.94414            7.830362            6.137356          3.46
# 5008          NaN            6.999135            6.576763          4.02
# 5009          NaN            7.250591            4.805081          2.13
# 5010  68001.33124            5.534388            7.130144          5.44
# 5011  65510.58180            5.992305            6.792336          4.07
#
#       avg_population         price  \
# 0        23086.80050  1.059034e+06
# 1        40173.07217  1.505891e+06
# 2        36882.15940  1.058988e+06
# 3        34310.24283  1.260617e+06
# 4        26354.10947  6.309435e+05
# ...              ...           ...
# 5007     22837.36103  1.060194e+06
# 5008     25616.11549  1.482618e+06
# 5009     33266.14549  1.030730e+06
# 5010     42625.62016  1.198657e+06
# 5011     46501.28380  1.298950e+06
#
#                                                 address
# 0     208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1     188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2     9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                             USS Barnett\nFPO AP 44820
# 4                            USNS Raymond\nFPO AE 09386
# ...                                                 ...
# 5007                   USNS Williams\nFPO AP 30153-7653
# 5008              PSC 9258, Box 8489\nAPO AA 42991-3352
# 5009  4215 Tracy Garden Suite 076\nJoshualand, VA 01...
# 5010                          USS Wallace\nFPO AE 73316
# 5011  37778 George Ridges Apt. 509\nEast Holly, NV 2...
#
# [5012 rows x 7 columns]

# %%
data.head()
# Out:
#     avg_income  avg_area_house_age  avg_area_num_rooms  avg_bedrooms  \
# 0  79545.45857            5.682861            7.009188          4.09
# 1  79248.64245            6.002900            6.730821          3.09
# 2  61287.06718            5.865890            8.512727          5.13
# 3  63345.24005            7.188236            5.586729          3.26
# 4  59982.19723            5.040555            7.839388          4.23
#
#    avg_population         price  \
# 0     23086.80050  1.059034e+06
# 1     40173.07217  1.505891e+06
# 2     36882.15940  1.058988e+06
# 3     34310.24283  1.260617e+06
# 4     26354.10947  6.309435e+05
#
#                                              address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                          USS Barnett\nFPO AP 44820
# 4                         USNS Raymond\nFPO AE 09386

# %%
data.isnull().sum()
# Out:
# avg_income            3
# avg_area_house_age    2
# avg_area_num_rooms    1
# avg_bedrooms          0
# avg_population        3
# price                 0
# address               1
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
X = data.iloc[:,0:5]

# %%
X
# Out:
#        avg_income  avg_area_house_age  avg_area_num_rooms  avg_bedrooms  \
# 0     79545.45857            5.682861            7.009188          4.09
# 1     79248.64245            6.002900            6.730821          3.09
# 2     61287.06718            5.865890            8.512727          5.13
# 3     63345.24005            7.188236            5.586729          3.26
# 4     59982.19723            5.040555            7.839388          4.23
# ...           ...                 ...                 ...           ...
# 5000  65510.58180            5.992305            6.792336          4.07
# 5005  69639.14090            5.007510            7.778375          6.05
# 5007  60567.94414            7.830362            6.137356          3.46
# 5010  68001.33124            5.534388            7.130144          5.44
# 5011  65510.58180            5.992305            6.792336          4.07
#
#       avg_population
# 0        23086.80050
# 1        40173.07217
# 2        36882.15940
# 3        34310.24283
# 4        26354.10947
# ...              ...
# 5000     46501.28380
# 5005     54056.12843
# 5007     22837.36103
# 5010     42625.62016
# 5011     46501.28380
#
# [5005 rows x 5 columns]

# %%
y = data["price"]

# %%
y
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
#             ...
# 5000    1.298950e+06
# 5005    1.381831e+06
# 5007    1.060194e+06
# 5010    1.198657e+06
# 5011    1.298950e+06
# Name: price, Length: 5005, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=0)

# %%
X_train.shape
# Out:
# (3503, 5)

# %%
y_train.shape
# Out:
# (3503,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test, y_test)
# Out:
# 0.9190906063558046

# %%
lr.predict([[79248.64245,6.002900,6.730821,3.09,40173.07217]])
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1496205.73195933])
